# %%
import pandas as pd
data_frame = pd.read_csv('ticks.csv')
data_frame.shape
# Out:
# (2213, 15)

# %%
data_frame.describe()
# Out:
#            Pitches    Avg Stars   Your Stars       Length   Rating Code
# count  2213.000000  2213.000000  2213.000000  1782.000000   2213.000000
# mean      1.253954     2.573339     2.505197    72.265993   7742.776774
# std       0.849231     0.644656     1.093130   146.180186   7706.841049
# min       1.000000    -1.000000    -1.000000     4.000000      0.000000
# 25%       1.000000     2.100000     2.000000    20.000000   2400.000000
# 50%       1.000000     2.600000     3.000000    50.000000   3200.000000
# 75%       1.000000     3.000000     3.000000    70.000000  20008.000000
# max      12.000000     4.000000     4.000000  2700.000000  32250.000000

# %%
print(data_frame['Length'].hist())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
data_frame.head()
# Out:
#          Date                        Route Rating  \
# 0  2019-12-21  When Turkey Vultures Attack     V1
# 1  2019-12-21         Magic Man and Diablo     V0
# 2  2019-12-21   Super Trooper (Right Exit)     V7
# 3  2019-12-21          Bozo's Porno Circus     V0
# 4  2019-12-21      Eve, The Mother of Cain     V1
#
#                                                Notes  \
# 0                           Fun warm up! With Sarah.
# 1                               Warm up. With Sarah.
# 2  Couldn&#39;t make the first move, again, but s...
# 3                               Warm up. With Sarah.
# 4                               Warm up. With Sarah.
#
#                                                  URL  Pitches  \
# 0  https://www.mountainproject.com/route/11817381...        3
# 1  https://www.mountainproject.com/route/11817377...        2
# 2  https://www.mountainproject.com/route/11801230...        1
# 3  https://www.mountainproject.com/route/11701828...        1
# ...

# %%
group = data_frame.groupby('Length')
group.mean()
# Out:
#           Pitches  Avg Stars  Your Stars   Rating Code
# Length
# 4.0      1.000000   1.500000    2.000000  20008.000000
# 5.0      1.000000   2.116667    2.000000  20165.833333
# 6.0      1.000000   2.525000    2.625000  20046.500000
# 7.0      1.000000   1.766667    2.333333  20171.666667
# 8.0      1.043478   2.192754    2.289855  20155.231884
# ...           ...        ...         ...           ...
# 900.0    6.000000   2.000000    2.000000   2500.000000
# 1000.0   7.500000   2.950000    3.000000   3400.000000
# 1700.0  12.000000   3.600000    4.000000   1500.000000
# 2000.0  10.000000   3.200000    3.000000   1600.000000
# 2700.0   1.000000   4.000000    4.000000   1400.000000
#
# [76 rows x 4 columns]
